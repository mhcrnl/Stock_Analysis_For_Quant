# %% [markdown]
# # Big Three Trading Strategy

# %% [markdown]
# 20 Period Simple Moving Average
#
# 40 Period Simple Moving Average
#
# 80 Period Simple Moving Average
#
#
# https://tradingstrategyguides.com/big-three-trading-strategy/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
"""
# fix_yahoo_finance is used to fetch data 
import fix_yahoo_finance as yf
yf.pdr_override()
"""
import pandas_datareader as yf
import datetime

# %%
# input
symbol = 'AAPL'
start = datetime.datetime(2018, 1, 1)
end   = datetime.datetime(2020, 4, 13)  

# Read data 
df = yf.get_data_yahoo(symbol,start,end)

# View Columns
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-01-02  172.300003  169.259995  170.160004  172.259995  25555900.0
# 2018-01-03  174.550003  171.960007  172.529999  172.229996  29517900.0
# 2018-01-04  173.470001  172.080002  172.539993  173.029999  22434600.0
# 2018-01-05  175.369995  173.050003  173.440002  175.000000  23660000.0
# 2018-01-08  175.610001  173.929993  174.350006  174.350006  20567800.0
#
#              Adj Close
# Date
# 2018-01-02  166.804016
# 2018-01-03  166.774963
# 2018-01-04  167.549622
# 2018-01-05  169.457214
# 2018-01-08  168.827820

# %%
df['SMA_20'] = df['Adj Close'].rolling(20).mean()
df['SMA_40'] = df['Adj Close'].rolling(40).mean()
df['SMA_80'] = df['Adj Close'].rolling(80).mean()

# %%
df.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-04-06  263.109985  249.380005  250.899994  262.470001  50455100.0
# 2020-04-07  271.700012  259.000000  270.799988  259.429993  50721800.0
# 2020-04-08  267.369995  261.230011  262.739990  266.070007  42223800.0
# 2020-04-09  270.070007  264.700012  268.700012  267.989990  40529100.0
# 2020-04-13  273.700012  265.829987  268.309998  273.250000  32663400.0
#
#              Adj Close      SMA_20      SMA_40      SMA_80
# Date
# 2020-04-06  262.470001  251.225000  277.085748  289.374899
# 2020-04-07  259.429993  249.929500  275.532748  289.241162
# 2020-04-08  266.070007  249.461501  274.194249  289.181821
# 2020-04-09  267.989990  250.449500  272.713998  289.100465
# 2020-04-13  273.250000  250.213500  271.423499  289.026123

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(df.index, df['Adj Close'], label='Price')
ax.plot(df.index, df['SMA_20'], label = '20-days SMA')
ax.plot(df.index, df['SMA_40'], label = '40-days SMA')
ax.plot(df.index, df['SMA_80'], label = '80-days SMA')

ax.legend(loc='best')
ax.set_ylabel('Price')
ax.set_title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')

# %% [markdown]
# ## Closer View
#
# plot different dates

# %%
new_dates = df['2017-01-01':'2018-12-31']
new_dates.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-01-02  172.300003  169.259995  170.160004  172.259995  25555900.0
# 2018-01-03  174.550003  171.960007  172.529999  172.229996  29517900.0
# 2018-01-04  173.470001  172.080002  172.539993  173.029999  22434600.0
# 2018-01-05  175.369995  173.050003  173.440002  175.000000  23660000.0
# 2018-01-08  175.610001  173.929993  174.350006  174.350006  20567800.0
#
#              Adj Close  SMA_20  SMA_40  SMA_80
# Date
# 2018-01-02  166.804016     NaN     NaN     NaN
# 2018-01-03  166.774963     NaN     NaN     NaN
# 2018-01-04  167.549622     NaN     NaN     NaN
# 2018-01-05  169.457214     NaN     NaN     NaN
# 2018-01-08  168.827820     NaN     NaN     NaN

# %%
plt.figure(figsize=(16,10))
plt.plot(new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA')
plt.plot(new_dates['SMA_40'], label = '40-days SMA')
plt.plot(new_dates['SMA_80'], label = '80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index ,y=new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA')
plt.plot(new_dates['SMA_40'], label = '40-days SMA')
plt.plot(new_dates['SMA_80'], label = '80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index ,y=new_dates['Adj Close'], fmt='r-', label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA', color='b')
plt.plot(new_dates['SMA_40'], label = '40-days SMA', color='y')
plt.plot(new_dates['SMA_80'], label = '80-days SMA', color='green')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Date')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')
